# %%
from azureml.core import Workspace, Dataset, Environment

subscription_id = '92b2ba30-15c6-4cb9-bdc6-7dee778f2a6b'
resource_group = 'AzureML'
workspace_name = 'AzureML'

ws = Workspace(subscription_id, resource_group, workspace_name)

# %%
envs = Environment.list(workspace=ws)

for env in envs:
    if env.startswith("AzureML"):
        print("Name",env)
        print("packages", envs[env].python.conda_dependencies.serialize_to_string())
# Out:
# Name AzureML-Tutorial
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - azureml-widgets==1.1.0rc0
#   - azureml-pipeline-core==1.1.0rc0
#   - azureml-pipeline-steps==1.1.0rc0
#   - azureml-opendatasets==1.1.0rc0
#   - azureml-automl-core==1.1.0rc0
#   - azureml-automl-runtime==1.1.0rc0
#   - azureml-train-automl-client==1.1.0rc0
#   - azureml-train-automl-runtime==1.1.0rc0
#   - azureml-train-automl==1.1.0rc0
#   - azureml-train==1.1.0rc0
#   - azureml-sdk==1.1.0rc0
#   - azureml-interpret==1.1.0rc0
#   - azureml-tensorboard==1.1.0rc0
#   - azureml-mlflow==1.1.0rc0
#   - mlflow
#   - sklearn-pandas
# - pandas
# - numpy
# - tqdm
# - scikit-learn
# - matplotlib
# name: azureml_b6eaaeb045c6980face53654f16f9f00
#
# Name AzureML-Minimal
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
# name: azureml_6471a03bdeb42d91af2ab0b87624e989
#
# Name AzureML-Chainer-5.1.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - chainer==5.1.0
#   - cupy-cuda90==5.1.0
#   - mpi4py==3.0.0
# name: azureml_17ca93a67cd632dad53e43fd39f15573
#
# Name AzureML-PyTorch-1.2-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.2
#   - torchvision==0.4.0
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_cc84db7885d972d3eda1477733178355
#
# Name AzureML-TensorFlow-1.12-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow==1.12
#   - horovod==0.15.2
# name: azureml_b9844e6437f2faa4cb12fb743554defc
#
# Name AzureML-TensorFlow-1.13-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow==1.13.1
#   - horovod==0.16.1
# name: azureml_ca26d6b0c13781a357f38c2e75e1e0cc
#
# Name AzureML-PyTorch-1.1-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.1
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_93fafb96b607a560690c5198019a6562
#
# Name AzureML-TensorFlow-1.10-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow==1.10
#   - horovod==0.15.2
# name: azureml_33506ed4f27153a6974b0e5fe3e31090
#
# Name AzureML-PyTorch-1.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.0
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
# name: azureml_ec22d2b5848bb6925bb6fb5a8ed2c6f1
#
# Name AzureML-TensorFlow-1.12-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow-gpu==1.12.0
#   - horovod==0.15.2
# name: azureml_90159573c856ae2061c8bdd78bd5fc08
#
# Name AzureML-TensorFlow-1.13-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow-gpu==1.13.1
#   - horovod==0.16.1
# name: azureml_da21949067ddf6cf9ed89f186a63e173
#
# Name AzureML-Chainer-5.1.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - chainer==5.1.0
#   - mpi4py==3.0.0
# name: azureml_bfcec1d3f62495d0b34d4d0330ca6b37
#
# Name AzureML-PyTorch-1.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.0
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
# name: azureml_ec22d2b5848bb6925bb6fb5a8ed2c6f1
#
# Name AzureML-Scikit-learn-0.20.3
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - scikit-learn==0.20.3
#   - scipy==1.2.1
#   - numpy==1.16.2
#   - joblib==0.13.2
# name: azureml_9d41fd4fdbf8832094d216ccd09fd562
#
# Name AzureML-PyTorch-1.2-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.2
#   - torchvision==0.4.0
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_cc84db7885d972d3eda1477733178355
#
# Name AzureML-PyTorch-1.1-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.1
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_93fafb96b607a560690c5198019a6562
#
# Name AzureML-TensorFlow-1.10-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow-gpu==1.10.0
#   - horovod==0.15.2
# name: azureml_9a58fe862d02fd929d234bf9633c9cae
#
# Name AzureML-PyTorch-1.3-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.3
#   - torchvision==0.4.1
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_990ced626fce6c181d10505ea9ef4ca4
#
# Name AzureML-TensorFlow-2.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow==2.0
#   - horovod==0.18.1
# name: azureml_a78944093d964a26118a0b356ee25e9c
#
# Name AzureML-PyTorch-1.3-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.3
#   - torchvision==0.4.1
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_990ced626fce6c181d10505ea9ef4ca4
#
# Name AzureML-TensorFlow-2.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - tensorflow-gpu==2.0.0
#   - horovod==0.18.1
# name: azureml_c083ab1ddd4e5921d3e5de2cc191039d
#
# Name AzureML-PySpark-MmlSpark-0.15
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
# name: azureml_6714af7ef17549b5607250b6437b69f4
#
# Name AzureML-AutoML
# packages channels:
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-pipeline-core==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-automl-core==1.1.0rc0
#   - azureml-automl-runtime==1.1.0rc0
#   - azureml-train-automl-client==1.1.0rc0
#   - azureml-train-automl-runtime==1.1.0rc0
#   - azureml-explain-model==1.1.0rc0
#   - inference-schema
# - numpy>=1.16.0,<=1.16.2
# - pandas>=0.21.0,<=0.23.4
# - py-xgboost<=0.80
# - fbprophet==0.5
# - setuptools-git
# name: azureml_ca402ead8d0104f0dff29be55f76253e
#
# Name AzureML-PyTorch-1.4-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.4.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_ddcfaea42ee366e2844293801f0727f1
#
# Name AzureML-PyTorch-1.4-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-train-restclients-hyperdrive==1.1.0rc0
#   - azureml-train-core==1.1.0rc0
#   - torch==1.4.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_ddcfaea42ee366e2844293801f0727f1
#
# Name AzureML-VowpalWabbit-8.8.0
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-dataprep[fuse,pandas]
# name: azureml_ff025c81fca71129afc9a45878e20645
#
# Name AzureML-Hyperdrive-ForecastDNN
# packages dependencies:
# - python=3.7
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-pipeline-core==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-automl-core==1.1.0rc0
#   - azureml-automl-runtime==1.1.0rc0
#   - azureml-train-automl-client==1.1.0rc0
#   - azureml-train-automl-runtime==1.1.0rc0
#   - azureml-contrib-automl-dnn-forecasting==1.1.0rc0
# name: azureml_ee345e3fabb926f9876128aea27de5c1
#
# Name AzureML-AutoML-GPU
# packages name: gpuexp
# dependencies:
# - python=3.6.2
# channels:
# - conda-forge
#
# Name AzureML-AutoML-DNN-GPU
# packages name: gpuexp
# dependencies:
# - python=3.6.2
# channels:
# - conda-forge
#
# Name AzureML-AutoML-DNN
# packages channels:
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.1.0rc0
#   - azureml-pipeline-core==1.1.0rc0
#   - azureml-telemetry==1.1.0rc0
#   - azureml-defaults==1.1.0rc0
#   - azureml-automl-core==1.1.0rc0
#   - azureml-automl-runtime==1.1.0rc0
#   - azureml-train-automl-client==1.1.0rc0
#   - azureml-train-automl-runtime==1.1.0rc0
#   - azureml-explain-model==1.1.0rc0
#   - inference-schema
#   - pytorch-transformers==1.0.0
#   - spacy==2.1.8
#   - https://aka.ms/automl-resources/packages/en_core_web_sm-2.1.0.tar.gz
# - pandas>=0.21.0,<=0.23.4
# - numpy>=1.16.0,<=1.16.2
# - py-xgboost<=0.80
# - fbprophet==0.5
# - setuptools-git
# - pytorch=1.1.0
# - cudatoolkit=9.0
# name: azureml_f626e2fc35997444a8cc80b523b142e2
